# %% [markdown]
# DeepLearning :-

# %%
import numpy as np

# Sigmoid activation function
def sigmoid(x):
  return 1/(1+np.exp(-x))

X=np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

y=np.array([[0], [0], [0], [1]])

# Initialize weights and bias
weights=np.random.rand(2,1)
bias=np.random.rand(1)
learning_rate=0.1

# Training the neural network
for epoch in range(10000):
  z=np.dot(X, weights)+bias
  y_pred=sigmoid(z)

  error=y-y_pred
  gradient=y_pred * (1-y_pred)

  weights+=learning_rate * np.dot(X.T*gradient)
  bias += learning_rate*np.sum(error*gradient)

  # Testing
  print("AND Gate Output:")
  for i in X:
    output=sigmoid(np.dot(i,weights)+bias)
    print(i,"->", round(output[0]))

# %% [markdown]
# student pass/fail deep learning model :-

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import sequential
from tensorflow.keras.layers import Dense


data = {
    "Study_Hours":[6,5,4,3,2,1,6,6,4,5]
    "Attendence":[95,90,85,34,65,76,34,65,35,75]
    "Previous_Marks":[90,43,65,25,69,76,45,89,67,87]
    "Pass":[1,1,1,0,0,0,1,1,1,0]
}

df = pd.DataFrame(data)


x = df[["Study_Hours","Attendance","Previous_Marks"]]
y = df["Pass"]


x_train, x_test, y_train, y_test = train_test_split(

)


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.tr


model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)


model.fit(x_train, y_train, epoch=100, batch_size=2, verbose=1)


loss, accuracy = model.evalute(x_test, y_test)
print("Accuracy:", accuracy)


new_student = [[5,90,82]]
new_student = scaler.transform(new_student)


prediction = model.predict(new_student)

if prediction[0][0] >= 0.5:
    print("prediction: PASS")
else:
    print("Prediction: FAIL")
