# %% [markdown]
# Make a project scientific calculator using python. including 20 functions.

# %%
def line(n=43):
  print("="*n)

def next():
  print("\n")

def space():
  print("\t"*3)

line()
print( "\t" ,"Choose the calculate type:-")
print("1. Simple calculater")
print("2. Alegrabric calculater")
line()

choose=int(input("Enter from choice: "))


if choose==1:
  print("You choose Simple calculater")
  print("choose from +, -, *, / ")
  line()
  cal=(input("Enter the action: "))
  if cal=="+":
    a=int(input("enter no: "))
    b=int(input("enter no: "))
    print(f"Addition of {a} and {b} is {a+b}")
    line()
  elif cal=="-":
    a=int(input("enter no: "))
    b=int(input("enter no: "))
    print(f"Subtraction of {a} and {b} is {a-b}")
    line()
  elif cal=="*":
    a=int(input("enter no: "))
    b=int(input("enter no: "))
    print(f"Multiplication of {a} and {b} is {a*b}")
    line()
  elif cal=="/":
    a=int(input("enter no: "))
    b=int(input("enter no: "))
    print(f"Division of {a} and {b} is {a/b}")
    line()
  else:
    line()
    print("invalid action !!")
elif choose==2:
   print("\t","You choose Alegrabric calculater:")
   print("choose from **, %, //")
   line()
   cal2=(input("Enter the action: "))
   if cal2=="**":
     a=int(input("enter no: "))
     b=int(input("enter no: "))
     print(f"{a} to the power of {b} is {a**b}")
     line()
   elif cal2=="%":
     a=int(input("enter no: "))
     b=int(input("enter no: "))
     print(f"Remainder of {a} and {b} is {a%b}")
     line()
   elif cal2=="//":
    a=int(input("enter no: "))
    b=int(input("enter no: "))
    print(f"Floor division of {a} and {b} is {a//b}")
    line()
   else:
    line()
    print("invalid action !!")
else:
  line()
  print("invalid choice !!")
# Out:
# ...
# 	 Choose the calculate type:-
# 1. Simple calculater
# 2. Alegrabric calculater
# ...
# 	 You choose Alegrabric calculater:
# choose from **, %, //
# ...
# 23 to the power of 2 is 529
# ...
