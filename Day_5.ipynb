# %%
# Recursion:-

def count(n):
  if n==0:
    return
  print("hello")
  count(n-1)

count(4)
# Out:
# hello
# hello
# hello
# hello

# %%
# Function 

def printn():
    print("hello world")

printn()

# %%
def rot():
  brain=input("likhe: ")
  print(brain)

rot()

# %%
th1=["cat", "dog", "bird"]
th2=["world", "wor", "wo"]
th3=["hello", "hell", "he"]

def syntax():
  for i in (th1,th2,th3):
    print(i)
    # print(syntax())

syntax()

# %%
def add(a,b):
  print(a+b)

add(12,23)
print(add(a=12,b=23))

# %%
def add(a,b,c):
  return a+b+c
# add(a=100,10,30)          #         X
# add(100,b=10,30)          #         X
add(100,10,c=30)
add(100,10,30)

# %%
def l(**l):
  print(l)

l(name="lucky", name2="ankit bhau")

# %%
# number of cube

hell=lambda : print("hello")
hell()

# %%
# Recursion:-

def count(n):
  if n==0:
    return
  print("hello")
  count(n-1)

count(4)

# %%
def line():
    print("="*40)
def next():
    print("\n")


line()
print("               Marksheet            ")
line()

name=input("Enter your name:")
m1=int(input("Enter marks of first subject:"))
m2=int(input("Enter marks of second subject:"))

total=m1+m2
percentage=(total/200)*100

print("\nTotal number:", total)
print("percentage:", percentage)
next()
line()
print("                RESULT               ")
line()

print("Name\t\t : \t",name)
print("Total Marks\t : \t",total)
print("percentage\t : \t",percentage)
next()
# Out:
# ========================================
#                Marksheet
# ========================================
#
# Total number: 66
# percentage: 33.0
#
#
# ========================================
#                 RESULT
# ========================================
# Name		 : 	 ksadhfj
# Total Marks	 : 	 66
# percentage	 : 	 33.0
