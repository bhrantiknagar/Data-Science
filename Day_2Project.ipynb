# %%
name=input("enter student name:")
rollno=int(input("enter student rollno:"))
print("\n")
print("===== MENU =====")
print("1. Result Calculator")
print("2. Attendance Checker")
print("3. Scholarship Checker")
print("\n")

# stud1={
#     "name":"lucky"
# }

# stud2={
#     "name":"bhrantik"
# }

# stud3={
#     "name":"rohan"
# }

user=73

choice=int(input("Enter your choice (1-3):"))
print("\n")

if choice==1:
  print("your choice is Result calculator")
  print("\n")
  m1=int(input("Enter marks of first subject:"))
  m2=int(input("Enter marks of second subject:"))

  total=m1+m2
  percentage=(total/200)*100

  print("\nTotal number:", total)
  print("percentage:", percentage)

  print("\n")
  print("                RESULT               ")

  print("Name\t\t : \t",name)
  print("Total Marks\t : \t",total)
  print("percentage\t : \t",percentage)

elif choice==2:
  print("your choice is Attendance Checker")
  tot_days=200
  days=int(input("enter days:"))
  print("\n")
  print("total days:",tot_days)
  print("present days:",days)
  
  
elif choice==3:
  print("your choice is Scholarship Checker")
  schol=float(input("enter scholarship points:"))
#   if schol

else:
  print("invalid choice select (1-3)")
